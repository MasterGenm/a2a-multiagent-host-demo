# %% [markdown]
# ## Application Setup and Launch

# %%
import os
import sys
import nest_asyncio
import asyncio
from fastapi import FastAPI
from fastapi.middleware.wsgi import WSGIMiddleware
import httpx
from functools import wraps
import datetime

# 🧩 本地导入路径，根据放置的项目结构调整
sys.path.insert(0, r"E:\Github\a2a-samples\samples\python")

from components.api_key_dialog import api_key_dialog
from components.page_scaffold import page_scaffold
from pages.agent_list import agent_list_page
from pages.conversation import conversation_page
from pages.event_list import event_list_page
from pages.home import home_page_content
from pages.settings import settings_page_content
from pages.task_list import task_list_page
from service.server.server import ConversationServer
from state import host_agent_service
from state.state import AppState
import mesop as me
from contextlib import asynccontextmanager
from dotenv import load_dotenv
import uvicorn
import threading

# ✅ 允许在 Notebook 中多次运行 asyncio
nest_asyncio.apply()

# ✅ 加载 .env 环境变量
load_dotenv()

# ===== 1. 安全配置封装与审计模块 =====
class SecurityManager:
    """
    一个中心化的类，用于封装安全配置和处理审计日志。
    """
    def __init__(self):
        # (封装) 将安全策略作为配置封装在此类中
        self.policy = me.SecurityPolicy(allowed_script_srcs=['https://cdn.jsdelivr.net'])
        # (审计) 为审计日志创建一个简单的列表（在生产环境中，这应该是一个真正的日志文件或服务）
        self.audit_log = []

    def log_event(self, event_type: str, details: str):
        """
        记录一个带有时间戳的安全事件。
        """
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        log_entry = f"[{timestamp}] - {event_type}: {details}"
        self.audit_log.append(log_entry)
        # 为了在 notebook 中立即看到反馈，我们也打印到控制台
        print(f"AUDIT LOG: {log_entry}")

# 创建 SecurityManager 的全局单例
security_manager = SecurityManager()


# ===== 2. 权限管理模块 (与审计模块集成) =====
class AuthService:
    def __init__(self, security_manager_instance: SecurityManager):
        # 权限现在包含一个新的 'audit' 页面，仅限 admin
        self._user_permissions = {
            "guest": ["home", "conversation"],
            "admin": ["home", "conversation", "agents", "event_list", "task_list", "settings", "audit"]
        }
        self.current_user_role = "guest"
        self.security_manager = security_manager_instance

    def check_permission(self, page_key: str) -> bool:
        return page_key in self._user_permissions.get(self.current_user_role, [])

    def set_user_role(self, role: str):
        if role in self._user_permissions and role != self.current_user_role:
            old_role = self.current_user_role
            self.current_user_role = role
            # (审计) 当角色发生变化时，记录事件
            self.security_manager.log_event(
                "ROLE_CHANGE_SUCCESS",
                f"User role changed from '{old_role}' to '{self.current_user_role}'"
            )
            return True
        elif role not in self._user_permissions:
            self.security_manager.log_event(
                "ROLE_CHANGE_FAILURE",
                f"Attempted to change to an invalid role: '{role}'"
            )
        return False

# 将 security_manager 实例传入 AuthService
auth_service = AuthService(security_manager)


# ⚙️ 初始化 FastAPI & 客户端封装
class HTTPXClientWrapper:
    async_client: httpx.AsyncClient = None
    def start(self):
        self.async_client = httpx.AsyncClient(timeout=30)
    async def stop(self):
        await self.async_client.aclose()
        self.async_client = None
    def __call__(self):
        assert self.async_client is not None
        return self.async_client

httpx_client_wrapper = HTTPXClientWrapper()


# ===== 3. 动态页面注册 (与审计模块集成) =====
def register_page(path, title, page_key, on_load_fn):
    def decorator(func):
        # 从 security_manager 获取封装的策略
        @me.page(path=path, title=title, on_load=on_load_fn, security_policy=security_manager.policy)
        @wraps(func)
        def wrapper():
            # (审计) 在检查权限之前，先记录访问尝试
            has_permission = auth_service.check_permission(page_key)
            if not has_permission:
                security_manager.log_event(
                    "ACCESS_DENIED",
                    f"User '{auth_service.current_user_role}' was denied access to page '{page_key}' at path '{path}'"
                )
                me.text(f"您没有权限访问 {title} 页面。")
                return

            security_manager.log_event(
                "ACCESS_GRANTED",
                f"User '{auth_service.current_user_role}' was granted access to page '{page_key}' at path '{path}'"
            )
            func()
        return wrapper
    return decorator

def on_load(e: me.LoadEvent):
    state = me.state(AppState)
    me.set_theme_mode(state.theme_mode)
    # ... (其余 on_load 代码保持不变)
    if 'conversation_id' in me.query_params:
        state.current_conversation_id = me.query_params['conversation_id']
    else:
        state.current_conversation_id = ''
    uses_vertex_ai = os.getenv('GOOGLE_GENAI_USE_VERTEXAI', '').upper() == 'TRUE'
    api_key = os.getenv('GOOGLE_API_KEY', '')
    if uses_vertex_ai:
        state.uses_vertex_ai = True
    elif api_key:
        state.api_key = api_key
    else:
        state.api_key_dialog_open = True


# ===== 4. Conversation Retry & Loading 功能 =====
async def handle_backend_call(user_input: str) -> str:
    """模拟与后端或AI模型的异步交互"""
    await asyncio.sleep(2)
    if "fail" in user_input.lower():
        raise ConnectionError("模拟API调用失败")
    return f"这是对 “{user_input}” 的回复。Timestamp: {datetime.datetime.now().isoformat()}"


async def on_submit_message(e: me.ClickEvent):
    """处理用户发送新消息的事件"""
    state = me.state(AppState)
    if not state.current_user_input.strip(): return
    if not state.current_conversation_id:
        state.current_conversation_id = str(uuid.uuid4())
        state.conversations[state.current_conversation_id] = []
    
    conv = state.conversations[state.current_conversation_id]
    user_msg = Message(id=str(uuid.uuid4()), content=state.current_user_input, role="user")
    conv.append(user_msg)
    
    placeholder_msg = Message(id=str(uuid.uuid4()), content="", role="model", status="loading")
    conv.append(placeholder_msg)

    user_input_for_backend = state.current_user_input
    state.current_user_input = ""
    yield

    try:
        response = await handle_backend_call(user_input_for_backend)
        placeholder_msg.content = response
        placeholder_msg.status = "sent"
    except Exception:
        user_msg.status = "error"
        conv.pop()
    yield


async def on_retry_click(e: me.ClickEvent):
    """处理用户点击重试按钮的事件"""
    state = me.state(AppState)
    message_id = e.key
    conv = state.conversations.get(state.current_conversation_id)
    if not conv: return
    failed_msg = next((msg for msg in conv if msg.id == message_id), None)
    if not failed_msg: return
    failed_msg.status = "sent"
    placeholder_msg = Message(id=str(uuid.uuid4()), content="", role="model", status="loading")
    conv.append(placeholder_msg)
    yield
    try:
        response = await handle_backend_call(failed_msg.content)
        placeholder_msg.content = response
        placeholder_msg.status = "sent"
    except Exception:
        failed_msg.status = "error"
        conv.pop()
    yield


# ===== 5. 页面定义 =====
@register_page(path='/', title='Chat', page_key='home', on_load_fn=on_load)
def home_page():
    api_key_dialog()
    with page_scaffold():
        home_page_content(me.state(AppState))

@register_page(path='/agents', title='Agents', page_key='agents', on_load_fn=on_load)
def agents_page():
    agent_list_page(me.state(AppState))

@register_page(path='/conversation', title='Conversation', page_key='conversation', on_load_fn=on_load)
def conversation():
    conversation_page(me.state(AppState))

@register_page(path='/event_list', title='Event List', page_key='event_list', on_load_fn=on_load)
def events():
    event_list_page(me.state(AppState))

@register_page(path='/task_list', title='Task List', page_key='task_list', on_load_fn=on_load)
def tasks():
    task_list_page(me.state(AppState))

@register_page(path='/settings', title='Settings', page_key='settings', on_load_fn=on_load)
def settings():
    settings_page_content()

# (审计) 新增一个 admin 专属的审计日志页面
@register_page(path='/audit', title='Audit Log', page_key='audit', on_load_fn=on_load)
def audit_page():
    with page_scaffold():
        me.h1("Security Audit Log")
        me.text("显示最新的事件在最上方。")
        if not security_manager.audit_log:
            me.text("还没有审计事件被记录。")
        else:
            # 以相反的顺序显示日志，最新的在最前面
            for entry in reversed(security_manager.audit_log):
                me.text(entry, style=me.Style(font_family="monospace", white_space="pre-wrap"))


# ✅ 定义 lifespan 生命周期（FastAPI 启动钩子）
@asynccontextmanager
async def lifespan(app: FastAPI):
    httpx_client_wrapper.start()
    ConversationServer(app, httpx_client_wrapper())
    app.openapi_schema = None
    app.mount("/", WSGIMiddleware(me.create_wsgi_app(debug_mode=False)))
    app.setup()
    yield
    await httpx_client_wrapper.stop()

# ===== 6. 启动服务 =====
# 在这里切换角色以进行测试
auth_service.set_user_role("admin")

app = FastAPI(lifespan=lifespan)
host = os.environ.get('A2A_UI_HOST', '127.0.0.1')
port = int(os.environ.get('A2A_UI_PORT', '12000'))
host_agent_service.server_url = f"http://{host}:{port}"

def run_uvicorn():
    uvicorn.run(app, host=host, port=port, log_level="info")

threading.Thread(target=run_uvicorn, daemon=True).start()
print(f"✅ Uvicorn 已在后台启动： http://{host}:{port}  （浏览器打开这个地址试试）")
# Out:
# AUDIT LOG: [2025-07-21 01:32:30] - ROLE_CHANGE_SUCCESS: User role changed from 'guest' to 'admin'
# ✅ Uvicorn 已在后台启动： http://127.0.0.1:12000  （浏览器打开这个地址试试）
# INFO:     Started server process [20436]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:12000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:14330 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14330 - "GET /styles.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:14331 - "GET /zone.js/bundles/zone.umd.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:14333 - "GET /prod_bundle.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "GET /__web-components-module__/components/async_poller.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14350 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14352 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14354 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14360 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14362 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14364 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14372 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14374 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14376 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14382 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14384 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14387 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14393 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14395 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14397 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14403 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14405 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14407 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14413 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14415 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14417 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14423 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14425 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14427 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14435 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14437 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14439 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14445 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14447 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14449 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14457 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14459 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14461 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14467 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14469 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14471 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14477 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14479 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14481 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14487 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14489 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14492 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14498 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14500 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14502 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14508 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14510 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14512 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14518 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14523 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14525 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14531 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14533 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14535 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14541 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14543 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14545 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14551 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14554 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14557 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14563 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14565 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14567 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14575 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14577 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14579 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14589 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14591 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14593 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14601 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14604 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14606 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14612 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14614 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14616 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14624 - "POST /api_key/update HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14630 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14632 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14634 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14640 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14642 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14646 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14652 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14656 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14658 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14666 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14674 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14682 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14684 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14686 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14688 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14691 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14699 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14704 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14706 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14708 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14710 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14712 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14721 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14725 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14727 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14729 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14731 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14733 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14739 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14743 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14745 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14747 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14749 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14751 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14757 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14761 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14763 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14765 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14767 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14769 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14775 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14779 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14781 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14785 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14787 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14789 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14795 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14799 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14803 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14809 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14813 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14819 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14827 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14831 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14833 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14835 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14837 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14841 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14847 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14851 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14853 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14855 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14857 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14859 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14866 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14870 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14872 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14874 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14876 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14878 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14884 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14888 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14890 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14892 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14894 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14896 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14902 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14906 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14908 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14910 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14912 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14916 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14922 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14926 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14928 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14930 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14932 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14934 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14940 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14944 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14946 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14948 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14950 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14952 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14958 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14962 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14965 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14968 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14971 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14973 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14980 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14986 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14988 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14990 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14992 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14994 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:15000 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1029 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1031 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1033 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1035 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1037 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1043 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1047 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1049 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1051 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1053 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1055 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1061 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1065 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1067 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1069 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1071 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1074 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1080 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1084 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1086 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1088 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1090 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1092 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1098 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1100 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1108 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1113 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1115 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1117 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1119 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1121 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1127 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1131 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1134 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1137 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1139 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1141 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1147 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1153 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1155 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1157 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1159 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1161 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1169 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1173 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1175 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1177 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1179 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1181 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1187 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1191 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1193 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1195 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1197 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1199 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1205 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1209 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1215 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1221 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1227 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1231 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1233 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1235 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1237 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1239 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1245 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1249 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1251 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1253 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1255 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1257 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1263 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1267 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1269 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1271 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1273 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1275 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1281 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1285 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1287 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1289 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1291 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1293 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1300 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1304 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1306 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1308 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1310 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1312 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1318 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1322 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1324 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1326 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1328 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1330 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1336 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1340 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1342 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1344 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1346 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1348 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1354 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1358 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1360 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1362 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1364 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1366 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1372 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1376 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1378 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1380 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1382 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1384 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1390 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1394 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1396 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1398 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1400 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1402 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1410 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1414 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1416 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1418 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1420 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1422 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1428 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1432 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1434 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1436 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1438 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1440 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1446 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1450 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1452 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1454 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1456 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1458 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1465 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1470 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1472 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1474 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1476 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1478 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1485 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1489 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1491 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1493 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1495 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1497 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1503 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1507 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1509 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1511 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1513 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1515 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1521 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1525 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1527 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1529 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1531 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1533 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1539 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1545 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1551 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1555 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1557 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1559 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1561 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1564 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1571 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1575 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1577 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1579 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1581 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1583 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1589 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1593 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1595 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1597 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1599 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1601 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1607 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1611 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1617 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1619 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1621 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1623 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1629 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1633 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1635 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1637 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1639 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1641 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1647 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1651 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1653 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1655 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1657 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1659 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1665 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1669 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1671 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1673 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1675 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1677 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1683 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1687 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1689 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1691 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1693 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1695 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1703 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1705 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1711 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1715 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1718 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1721 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1723 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1725 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1731 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1735 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1737 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1739 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1741 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1743 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1751 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1755 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1757 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1759 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1761 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1763 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1769 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1773 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1775 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1777 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1779 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1781 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1787 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1791 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1793 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1795 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1797 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1799 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1805 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1809 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1811 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1813 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1815 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1817 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1824 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1828 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1830 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1832 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1834 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1836 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1842 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1846 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1848 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1850 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1852 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1854 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1860 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1864 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1866 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1868 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1870 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1872 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1880 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1884 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1886 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1888 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1890 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1892 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1899 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1904 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1906 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1908 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1911 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1913 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1923 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1927 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1931 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1933 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1935 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1937 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1943 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1947 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1949 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1951 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1953 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1955 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1962 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1966 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1970 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1972 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1974 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1977 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1983 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1987 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1989 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1991 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1993 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1995 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2001 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2005 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2007 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2009 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2011 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2013 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2020 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2024 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2026 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2028 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2030 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2032 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2038 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2042 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2044 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2046 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2048 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2050 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2056 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2058 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2064 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2068 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2070 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2072 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2074 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2076 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2082 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2087 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2090 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2092 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2094 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2096 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2108 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2114 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2116 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2118 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2120 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2122 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2128 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2133 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2135 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2137 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2139 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2141 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2147 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2151 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2153 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2155 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2157 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2159 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2165 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2171 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2177 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2181 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2183 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2187 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2189 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2191 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2197 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2201 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2203 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2205 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2207 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2209 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2215 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2219 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2221 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2224 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2226 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2228 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2234 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2238 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2240 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2242 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2244 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2247 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2253 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2257 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2259 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2261 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2263 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2265 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2271 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2276 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2279 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2283 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2287 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2291 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:14333 - "POST /__ui__ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2301 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2305 - "POST /agent/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2309 - "POST /conversation/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2311 - "POST /task/list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2313 - "POST /message/pending HTTP/1.1" 200 OK
# INFO:     127.0.0.1:2315 - "POST /agent/list HTTP/1.1" 200 OK

# %% [markdown]
# ## Asynchronous Task Framework

# %%
import asyncio, uuid, threading
from IPython.display import display, clear_output

# 1. 已有漫长的同步函数
def run_pipeline_sync(user_input: str):
    import time
    time.sleep(5)                      
    return f"✅ 已处理: {user_input}"

# 2. 把同步函数丢进线程池 -> 变异步
async def run_pipeline_async(user_input: str):
    return await asyncio.to_thread(run_pipeline_sync, user_input)

# 3. ===== 以下是异步任务框架 =====
TASK_STATUS, TASK_RESULT = {}, {}

async def _long_task(task_id: str, user_input: str):
    TASK_STATUS[task_id] = "Running"
    try:
        result = await run_pipeline_async(user_input)
        TASK_RESULT[task_id] = result
        TASK_STATUS[task_id] = "Success"
    except Exception as e:
        TASK_STATUS[task_id] = f"Failed: {e}"

def start_task(user_input: str):
    task_id = str(uuid.uuid4())
    TASK_STATUS[task_id] = "Pending"
    asyncio.create_task(_long_task(task_id, user_input))
    return task_id

def get_task_status(task_id: str):
    return TASK_STATUS.get(task_id, "Unknown Task")

async def run_and_display_task(user_input: str):
    task_id = start_task(user_input)
    while True:
        status = get_task_status(task_id)
        clear_output(wait=True)
        display(f"任务 {task_id[:8]}… 状态：{status}")
        if status == "Success" or status.startswith("Failed"):
            break
        await asyncio.sleep(1)
    display("任务结果：", TASK_RESULT.get(task_id, "（无结果）"))

# %% [markdown]
# ## Demo

# %%
async def demo_multi():
    ids = [start_task(f"MSG {i}") for i in range(5)]
    while True:
        clear_output(wait=True)
        for tid in ids:
            print(f"{tid[:8]}  →  {get_task_status(tid)}")
        if all(get_task_status(tid).startswith(("Success", "Failed")) for tid in ids):
            break
        await asyncio.sleep(1)
    print("\n全部完成！结果预览：")
    for tid in ids:
        print(tid[:8], "=>", TASK_RESULT.get(tid))

await demo_multi()
# Out:
# 89bda1d2  →  Success
# dfaac8ca  →  Success
# 0979d7a8  →  Success
# eeefe7c1  →  Success
# dad75834  →  Success
#
# 全部完成！结果预览：
# 89bda1d2 => ✅ 已处理: MSG 0
# dfaac8ca => ✅ 已处理: MSG 1
# 0979d7a8 => ✅ 已处理: MSG 2
# eeefe7c1 => ✅ 已处理: MSG 3
# dad75834 => ✅ 已处理: MSG 4
# AUDIT LOG: [2025-07-21 01:32:54] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:55] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:58] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:58] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:59] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:59] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:32:59] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:00] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:00] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:00] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:01] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:01] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:01] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:02] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:02] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:02] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:02] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:03] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:03] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:03] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:05] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:05] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:05] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:07] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:07] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:08] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:08] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:08] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:09] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:09] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:09] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:10] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:10] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:10] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:11] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:11] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:11] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:12] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:14] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:14] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:14] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:15] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:15] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:15] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:16] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:16] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:16] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:17] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:17] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:17] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:18] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:18] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:18] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:19] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:19] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:19] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:22] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:22] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:23] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:23] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:23] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:24] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:24] - ACCESS_GRANTED: User 'admin' was granted access to page 'home' at path '/'
# AUDIT LOG: [2025-07-21 01:33:24] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:25] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:25] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:26] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:27] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:27] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:28] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:29] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:29] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:30] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:30] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:31] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:32] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:32] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:33] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:34] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:34] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:34] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:35] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:36] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:36] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:37] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:37] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:37] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:38] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:38] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:38] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:39] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:39] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:39] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:40] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:40] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:40] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:41] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:41] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:41] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:42] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:42] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:42] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:43] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:43] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:43] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:44] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:44] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:44] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:45] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:45] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:45] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:45] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:46] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:46] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:47] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:47] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:47] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:47] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:48] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:48] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:49] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:49] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:49] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:50] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:50] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:50] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:50] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:50] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:51] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:51] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:51] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:51] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:52] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:52] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:52] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:53] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:53] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:54] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:54] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:54] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:54] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:55] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:55] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:55] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# Expecting value: line 1 column 1 (char 0)
# AUDIT LOG: [2025-07-21 01:33:55] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:55] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:55] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:58] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:58] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:58] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:59] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:59] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:33:59] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:00] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:00] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:00] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:01] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:01] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:01] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:02] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:02] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:03] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:03] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:03] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:05] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:05] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:05] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:07] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:07] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:07] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:08] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:08] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:08] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:09] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:09] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:09] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:10] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:10] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:10] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:11] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:11] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:11] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:12] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# Expecting value: line 1 column 1 (char 0)
# AUDIT LOG: [2025-07-21 01:34:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:14] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:15] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:15] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:15] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:17] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:17] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:17] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:18] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:19] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:19] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:20] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:21] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:22] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:22] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:22] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:22] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:23] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:23] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:23] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:23] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:24] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:24] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:24] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:25] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:25] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:25] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:26] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:26] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:26] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:26] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:26] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:26] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:27] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:28] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:28] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:29] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:30] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:30] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:31] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:32] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:32] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:33] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:34] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:34] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:35] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:36] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:37] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:37] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:38] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:39] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:39] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:40] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:41] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:41] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:42] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:43] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:43] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:44] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:45] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:45] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:46] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:46] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:47] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:47] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:48] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:48] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:49] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:49] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:50] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:50] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:50] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:51] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:52] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:52] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:52] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:53] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:54] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:54] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:55] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:56] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:57] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:58] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:59] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:34:59] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:00] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:01] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:01] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:02] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:03] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# Expecting value: line 1 column 1 (char 0)
# AUDIT LOG: [2025-07-21 01:35:03] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:04] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:06] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:07] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:08] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:08] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:09] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:10] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:10] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:11] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:11] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:12] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:13] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:14] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:15] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:16] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:16] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
# AUDIT LOG: [2025-07-21 01:35:17] - ACCESS_GRANTED: User 'admin' was granted access to page 'agents' at path '/agents'
